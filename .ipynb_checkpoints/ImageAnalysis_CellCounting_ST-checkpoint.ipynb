# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
import time
import timeit

# %%
test = cv2.imread('C:/Users/SWC/Desktop/Cellcounting_Example.jpeg',0)

# %%
plt.xticks([]),plt.yticks([])

plt.imshow(test)

# %%
ret,thresh1 = cv2.threshold(test,15,255,cv2.THRESH_BINARY_INV)


plt.xticks([]),plt.yticks([])

plt.imshow(thresh1)

# %%
# Setup SimpleBlobDetector parameters.
params = cv2.SimpleBlobDetector_Params()
 
# Change thresholds
params.minThreshold = 10;
params.maxThreshold = 200;
 
# Filter by Area.
params.filterByArea = True
params.minArea = 35
 
# Filter by Circularity
params.filterByCircularity = True
params.minCircularity = 0.01
 
# Filter by Convexity
params.filterByConvexity = True
params.minConvexity = 0.01
 
# Filter by Inertia
params.filterByInertia = True
params.minInertiaRatio = 0.01
 
# Create a detector with the parameters
ver = (cv2.__version__).split('.')
if int(ver[0]) < 3 :
    detector = cv2.SimpleBlobDetector(params)
else : 
    detector = cv2.SimpleBlobDetector_create(params)


start_time = timeit.default_timer()
elapsed = timeit.default_timer() - start_time

print(elapsed)
# Out:
# 2.1432512941011688e-05

# %%
## detect 
kpts = detector.detect(thresh1)

start_time = timeit.default_timer()
elapsed = timeit.default_timer() - start_time

print(elapsed)
# Out:
# 2.897917242727921e-05

# %%
# Set up the detector with default parameters.
detector = cv2.SimpleBlobDetector()

start_time = timeit.default_timer()
elapsed = timeit.default_timer() - start_time

print(elapsed)
# Out:
# 4.980795260944859e-05

# %%
# Draw detected blobs as red circles.
# cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS ensures the size of the circle corresponds to the size of blob
im_with_keypoints = cv2.drawKeypoints(thresh1, kpts, np.array([]), (0,0,255), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
 
# Show keypoints

# Show keypoints
cv2.imshow("Keypoints", im_with_keypoints)
cv2.waitKey(0)

start_time = timeit.default_timer()
elapsed = timeit.default_timer() - start_time

print(elapsed)
# Out:
# 7.516472848578815e-05

# %%
nblobs = len(kpts)

start_time = timeit.default_timer()
elapsed = timeit.default_timer() - start_time

print(elapsed)
# Out:
# 5.0109818971577624e-05

# %%
print(nblobs)

start_time = timeit.default_timer()
elapsed = timeit.default_timer() - start_time

print(elapsed)
# Out:
# 104
# 5.4335948306061255e-05
